# %%
sys.path.append('..')
from src.config import *
from src.preprocess import *
from src.eval import *
gezi.init_flags()

# %%
V = 4
FOLDS = 5
metric = 'score'
root = f'../working/offline/{V}/{FOLDS}'

# %%
d = gezi.read_metrics(root, ascending=True)
d.head(20)
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]
#                                                                                                   model  \
# 0                deberta-v3.len1280.flag-encode_targets-cls.concat_last.rank_loss_rate-0.1.trans-nl-ft3
# 0                            deberta-v3.len1280.flag-encode_targets-cls.rank_loss_rate-0.1.trans-nl-ft3
# 0                deberta-v3.len1280.flag-encode_targets-cls.concat_last.rank_loss_rate-0.1.trans-fr-ft2
# 0                deberta-v3.len1280.flag-encode_targets-cls.concat_last.rank_loss_rate-0.1.trans-cn-ft4
# 0                deberta-v3.len1280.flag-encode_targets-cls.concat_last.rank_loss_rate-0.1.trans-es-ft4
# 0                                               deberta-v3.len1280.flag-encode_targets-cls.trans-nl-ft3
# 0                                               deberta-v3.len1280.flag-encode_targets-cls.trans-es-ft4
# 0                                               deberta-v3.len1280.flag-encode_targets-cls.trans-fr-ft3
# ...
